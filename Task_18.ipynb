# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakthanekar70-hub/Assignment-no.17/blob/main/Task_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
upload  = files.upload()
print(upload)
# Out:
#      <input type="file" id="files-69340f88-f8ad-4721-9498-d65162c1e111" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69340f88-f8ad-4721-9498-d65162c1e111">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = pd.read_csv('/content/ford_car_dataset.csv')
df = filepath
df
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965    Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
#Display the first 10 rows and last 5 rows
print("First 10 rows: \n",df.head(10))
#Check the shape (number of rows and columns) and data types of all columns
print("Shape of the dataset: ",df.shape)
print("Shape of the dataset: \n",df.dtypes)
# Observations
# 1. Dataset contains rows and columns of Ford car information.
# 2. Shape shows total number of rows and columns.
# 3. dtypes shows which columns are numeric and which are categorical
# Out:
# First 10 rows:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5   Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6     Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7   Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8     Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9    Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0
# Shape of the dataset:  (17966, 9)
# Shape of the dataset:
#  model            object
# ...

# %%
# Missing values
print(df.isnull().sum())
# Duplicate rows
print("Duplicate Rows:", df.duplicated().sum())
# Remove duplicates
df = df.drop_duplicates()
# Obervations
# Missing values checked.
# Duplicate rows removed.
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
# Duplicate Rows: 154

# %%
# Statistical summary
print("Describe of the Dataset: \n",df.describe())
# Price
print("Price")
print("Min:", df["price"].min())
print("Max:", df["price"].max())
print("Mean:", df["price"].mean())
print("Median:", df["price"].median())

# Mileage
print("\nMileage")
print("Min:", df["mileage"].min())
print("Max:", df["mileage"].max())
print("Mean:", df["mileage"].mean())
print("Median:", df["mileage"].median())

# Year
print("\nYear")
print("Min:", df["year"].min())
print("Max:", df["year"].max())
print("Mean:", df["year"].mean())
print("Median:", df["year"].median())
# Out:
# Describe of the Dataset:
#                 year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000
# Price
# Min: 495
# Max: 54995
# ...

# %%
df[["price","mileage","year","engineSize","mpg"]].hist(figsize=(15,8))
plt.show()
# Obervation:
# Histograms show the distribution of numeric features.

# %%
# Model
plt.figure(figsize=(20,6))
sns.countplot(x=df["model"])
plt.xticks(rotation=45)
plt.show()

# Transmission
plt.figure(figsize=(6,4))
sns.countplot(x=df["transmission"])
plt.xticks(rotation=45)
plt.show()

# Fuel Type
plt.figure(figsize=(6,4))
sns.countplot(x=df["fuelType"])
plt.xticks(rotation=45)
plt.show()
# Obervation:
# Count plots show the frequency of each category.

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()
# Observation:
# Heatmap shows correlation between numeric features.

# %%
# Input Features
X = df.drop("price", axis=1)

# Output Feature
y = df["price"]
print("Independent Features: \n",X.columns)
print("\nDependent Feature: \n",y.name)
# Obervation:
# Price is the target (output) because we want to predict it.
# Remaining columns are input features.
# Out:
# Independent Features:
#  Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# Dependent Feature:
#  price

# %%
# Before Encoding
print(df[["fuelType", "transmission"]].head())

# One Hot Encoding
df = pd.get_dummies(df, columns=["fuelType", "transmission"])

# After Encoding
print(df.head())
# Out:
#   fuelType transmission
# 0   Petrol    Automatic
# 1   Petrol       Manual
# 2   Petrol       Manual
# 3   Petrol       Manual
# 4   Petrol    Automatic
#      model  year  price  mileage  tax   mpg  engineSize  fuelType_Diesel  \
# 0   Fiesta  2017  12000    15944  150  57.7         1.0            False
# 1    Focus  2018  14000     9083  150  57.7         1.0            False
# 2    Focus  2017  13000    12456  150  57.7         1.0            False
# 3   Fiesta  2019  17500    10460  145  40.3         1.5            False
# 4   Fiesta  2019  16500     1482  145  48.7         1.0            False
#
#    fuelType_Electric  fuelType_Hybrid  fuelType_Other  fuelType_Petrol  \
# 0              False            False           False             True
# 1              False            False           False             True
# 2              False            False           False             True
# 3              False            False           False             True
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Numeric columns
num = ["year", "mileage", "tax", "mpg", "engineSize"]

# Scaling
scaler = StandardScaler()
df[num] = scaler.fit_transform(df[num])

# First 5 rows
print(df.head())
# Out:
#      model      year  price   mileage       tax       mpg  engineSize  \
# 0   Fiesta  0.067059  12000 -0.382994  0.591380 -0.020597   -0.810561
# 1    Focus  0.554393  14000 -0.736317  0.591380 -0.020597   -0.810561
# 2    Focus  0.067059  13000 -0.562616  0.591380 -0.020597   -0.810561
# 3   Fiesta  1.041726  17500 -0.665405  0.510777 -1.737858    0.345325
# 4   Fiesta  1.041726  16500 -1.127749  0.510777 -0.908836   -0.810561
#
#    fuelType_Diesel  fuelType_Electric  fuelType_Hybrid  fuelType_Other  \
# 0            False              False            False           False
# 1            False              False            False           False
# 2            False              False            False           False
# 3            False              False            False           False
# 4            False              False            False           False
#
#    fuelType_Petrol  transmission_Automatic  transmission_Manual  \
# ...

# %%
# Load Dataset
df = pd.read_csv("ford_car_dataset.csv")

# Remove duplicates
df = df.drop_duplicates()

# Missing values
print(df.isnull().sum())

# Histogram
df[["price","mileage","year","engineSize","mpg"]].hist(figsize=(10,8))
plt.show()

# Count Plot
sns.countplot(x=df["fuelType"])
plt.show()

# Heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# Input and Output
X = df.drop("price", axis=1)
y = df["price"]

# One Hot Encoding
X = pd.get_dummies(X)

# Scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)

print("Preprocessing Completed")
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
# Preprocessing Completed
