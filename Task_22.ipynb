# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakthanekar70-hub/Assignment-no.17/blob/main/Task_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload = files.upload()
print(upload)
# Out:
#      <input type="file" id="files-3c4baf3f-9845-4740-8955-8fea4d28639f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c4baf3f-9845-4740-8955-8fea4d28639f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Q1
import pandas as pd

# Load Dataset
df = pd.read_csv("heart.csv")

# Display first 5 rows
print(df.head())

# Separate Features and Target
X = df.drop("HeartDisease", axis=1)
y = df["HeartDisease"]

# Encode Categorical Columns
X = pd.get_dummies(X, drop_first=True)

print(X.head())
print(y.head())
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0   40        140          289          0    172      0.0   True
# 1   49        160          180          0    156      1.0  False
# ...

# %%
#Q2
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train Shape:", X_train.shape)
print("X_test Shape :", X_test.shape)
print("y_train Shape:", y_train.shape)
print("y_test Shape :", y_test.shape)
# Out:
# X_train Shape: (734, 15)
# X_test Shape : (184, 15)
# y_train Shape: (734,)
# y_test Shape : (184,)

# %%
#Q3
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)

print("Model Trained Successfully")
# Out:
# Model Trained Successfully
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Q4
y_pred = model.predict(X_test)

print("Actual Values")
print(y_test.head(10).values)

print("Predicted Values")
print(y_pred[:10])
# Out:
# Actual Values
# [0 1 1 1 0 1 1 0 1 1]
# Predicted Values
# [0 0 1 1 0 1 1 0 1 1]

# %%
#Q5
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix")
print(cm)

TN = cm[0][0]
FP = cm[0][1]
FN = cm[1][0]
TP = cm[1][1]

print("True Negative :", TN)
print("False Positive:", FP)
print("False Negative:", FN)
print("True Positive :", TP)
# Out:
# Confusion Matrix
# [[67 10]
#  [17 90]]
# True Negative : 67
# False Positive: 10
# False Negative: 17
# True Positive : 90

# %%
#Q6
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

print("\nClassification Report\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 0.8532608695652174
# Precision: 0.9
# Recall   : 0.8411214953271028
# F1 Score : 0.8695652173913043
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        77
#            1       0.90      0.84      0.87       107
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %%
#Q7
import joblib

joblib.dump(model, "heart_model.pkl")

joblib.dump(X.columns.tolist(), "columns.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
#Q8
import joblib
import pandas as pd

model = joblib.load("heart_model.pkl")
columns = joblib.load("columns.pkl")

sample = pd.DataFrame([[40,1,0,140,289,0,1,172,0,0]],
columns=[
'Age',
'Sex',
'ChestPainType',
'RestingBP',
'Cholesterol',
'FastingBS',
'RestingECG',
'MaxHR',
'ExerciseAngina',
'Oldpeak'
])

sample = pd.get_dummies(sample)

sample = sample.reindex(columns=columns, fill_value=0)

prediction = model.predict(sample)

print("Prediction:", prediction)

if prediction[0] == 1:
    print("Heart Disease: Yes")
else:
    print("Heart Disease: No")
# Out:
# Prediction: [0]
# Heart Disease: No

# %%
#Q9
import streamlit as st

st.title("Heart Disease Prediction")

age = st.number_input("Age", 1, 120)

sex = st.selectbox("Sex", [0,1])

bp = st.number_input("Resting BP")

chol = st.number_input("Cholesterol")

maxhr = st.number_input("Max Heart Rate")

oldpeak = st.number_input("Old Peak")

predict = st.button("Predict")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1658/2656648291.py in <cell line: 0>()
#       1 #Q9
# ----> 2 import streamlit as st
#       3
#       4 st.title("Heart Disease Prediction")
#       5
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Q10
import streamlit as st
import pandas as pd
import joblib

model = joblib.load("heart_model.pkl")
columns = joblib.load("columns.pkl")

st.title("Heart Disease Prediction System")

age = st.number_input("Age", 1, 120)
sex = st.selectbox("Sex", [0,1])
bp = st.number_input("Resting BP")
chol = st.number_input("Cholesterol")
maxhr = st.number_input("Max Heart Rate")
oldpeak = st.number_input("Old Peak")

if st.button("Predict"):

    sample = pd.DataFrame([[age, sex, bp, chol, maxhr, oldpeak]],
    columns=[
        "Age",
        "Sex",
        "RestingBP",
        "Cholesterol",
        "MaxHR",
        "Oldpeak"
    ])

    sample = pd.get_dummies(sample)
    sample = sample.reindex(columns=columns, fill_value=0)

    prediction = model.predict(sample)

    if prediction[0] == 1:
        st.error("Heart Disease: Yes")
    else:
        st.success("Heart Disease: No")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1658/1817313447.py in <cell line: 0>()
#       1 #Q10
# ----> 2 import streamlit as st
#       3 import pandas as pd
#       4 import joblib
#       5
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
